# %%
import sqlite3
import pandas as pd

# %%
! pip install ipython-sql
! pip install panadas
# Out:
# ...
# DEPRECATION: Loading egg at c:\users\admin\appdata\local\programs\python\python312\lib\site-packages\gfpgan-1.3.8-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: celery 4.4.7 has a non-standard dependency specifier pytz>dev. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of celery or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: Loading egg at c:\users\admin\appdata\local\programs\python\python312\lib\site-packages\gfpgan-1.3.8-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...

# %%
cnn = sqlite3.connect("jupyter_sql_tutorial.db")

# %%
match=pd.read_csv("C:\\Users\\Admin\\Downloads\\iplmatches.csv")

# %%
match.to_sql("match",cnn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 match.to_sql("match",cnn)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:3008, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2813 """
#    2814 Write records stored in a DataFrame to a SQL database.
#    2815
# ...

# %%
# %load_ext sql

# %%
# %load_ext sqlite3
# Out:
# The sqlite3 module is not an IPython extension.

# %%
# %sql sqlite:///jupyter_sql_tutorial.db

# %%
# %%sql
#
# select * from match
# Out:
#  * sqlite:///jupyter_sql_tutorial.db
# Done.
# [(0, 335982, 'Bangalore', '2008-04-18', 'BB McCullum', 'M Chinnaswamy Stadium', 0, 'Royal Challengers Bangalore', 'Kolkata Knight Riders', 'Royal Challengers Bangalore', 'field', 'Kolkata Knight Riders', 'runs', 140.0, 'N', None, 'Asad Rauf', 'RE Koertzen'),
#  (1, 335983, 'Chandigarh', '2008-04-19', 'MEK Hussey', 'Punjab Cricket Association Stadium, Mohali', 0, 'Kings XI Punjab', 'Chennai Super Kings', 'Chennai Super Kings', 'bat', 'Chennai Super Kings', 'runs', 33.0, 'N', None, 'MR Benson', 'SL Shastri'),
#  (2, 335984, 'Delhi', '2008-04-19', 'MF Maharoof', 'Feroz Shah Kotla', 0, 'Delhi Daredevils', 'Rajasthan Royals', 'Rajasthan Royals', 'bat', 'Delhi Daredevils', 'wickets', 9.0, 'N', None, 'Aleem Dar', 'GA Pratapkumar'),
# ...

# %%
# %%sql
#
# create table school
# (s_id int(6),
# f_name varchar(24),
# l_name varchar(24),
# class varchar(6),
# division varchar (4),
# roll_no int(6),
# mobile_mo varchar(12),
# address text)
# Out:
#  * sqlite:///jupyter_sql_tutorial.db
# Done.
# []

# %% [markdown]
# <!-- # add columns
# # alter table school
# # add column (city varchar(32))
#
# #change size of columns
# # alter table school
# # modify column city varchar(24)
#
# #rename table name
# # alter table school rename S_data
#
# #delete  table data
# # truncate mukesh1
#
# #delete data of table
# # delete from s_data
# # where s_id = 1001
#
# #delete table with data
# # drop table mukesh1 -->

# %%
# %%sql
#
# use mukesh
#
# insert into school
# values(1002,"suresh","sirvi","MBBS","I","1001","8976534622","nathdwara")
#
# insert into school
# values(1003,"lalit","kumar","JEE","I","1992","9928885728","kota")
#
# insert into school
# values(1004,"rakesh","singh","Dfarma","IV","9982","9116570192","falna")
#
# alter table  school rename s_data
# #after changing table name school to s_data
# insert into s_data
# values(1005,"ramesh","janawa","Bfarma","V","9992","7877048252","gowada","rani");
#
# #update in old record whith new data
# update s_data
# set city="rani"
# where s_id = 1002 or s_id = 1003 or s_id = 1001
#
# #delete data of table
# delete from s_data
# where s_id = 1001
#
# #delete table with data
# drop table mukesh1
# Out:
#  * sqlite:///jupyter_sql_tutorial.db
# (sqlite3.OperationalError) near "use": syntax error
# [SQL: use mukesh
#
# insert into school
# values(1002,"suresh","sirvi","MBBS","I","1001","8976534622","nathdwara")
#
# insert into school
# values(1003,"lalit","kumar","JEE","I","1992","9928885728","kota")
#
# insert into school
# values(1004,"rakesh","singh","Dfarma","IV","9982","9116570192","falna")
#
# alter table  school rename s_data
# #after changing table name school to s_data
# insert into s_data
# values(1005,"ramesh","janawa","Bfarma","V","9992","7877048252","gowada","rani");]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
#
# select * from match limit 3
# Out:
#  * sqlite:///jupyter_sql_tutorial.db
# Done.
# [(0, 335982, 'Bangalore', '2008-04-18', 'BB McCullum', 'M Chinnaswamy Stadium', 0, 'Royal Challengers Bangalore', 'Kolkata Knight Riders', 'Royal Challengers Bangalore', 'field', 'Kolkata Knight Riders', 'runs', 140.0, 'N', None, 'Asad Rauf', 'RE Koertzen'),
#  (1, 335983, 'Chandigarh', '2008-04-19', 'MEK Hussey', 'Punjab Cricket Association Stadium, Mohali', 0, 'Kings XI Punjab', 'Chennai Super Kings', 'Chennai Super Kings', 'bat', 'Chennai Super Kings', 'runs', 33.0, 'N', None, 'MR Benson', 'SL Shastri'),
#  (2, 335984, 'Delhi', '2008-04-19', 'MF Maharoof', 'Feroz Shah Kotla', 0, 'Delhi Daredevils', 'Rajasthan Royals', 'Rajasthan Royals', 'bat', 'Delhi Daredevils', 'wickets', 9.0, 'N', None, 'Aleem Dar', 'GA Pratapkumar')]

# %%
# %%sql
#
# info match
# Out:
#  * sqlite:///jupyter_sql_tutorial.db
# (sqlite3.OperationalError) near "info": syntax error
# [SQL: info match]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
#
# select * from match
# where toss_dicision = "bat"
# Out:
# UsageError: Cell magic `%%sql` not found.

# %%
# %%sql
#
#
# delimiter $$
#
# create function num(num_in int)
# returns int
# begin
#     declare result int
#     set result = num_in * num_in
#     return result
# end $$
#
#
# delimiter
# Out:
#  * sqlite:///jupyter_sql_tutorial.db
# (sqlite3.OperationalError) near "delimiter": syntax error
# [SQL: delimiter $$
#
# create function num(num_in int)
# returns int
# begin
#     declare result int
#     set result = num_in * num_in
#     return result
# end $$
#
# delimiter]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
